# %%
import os
import sys
import pandas as pd

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.insert(0, PROJECT_ROOT)
os.chdir(PROJECT_ROOT)

from data.get_data import get_dataframe

# %%
df = get_dataframe("processed.csv")
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values('Date', ascending=False)
df
# Out:
#                   Fighter       Date                  Opp  Weight_Class  \
# 14763      Beneil Dariush 2023-12-02      Arman Tsarukyan   Lightweight
# 7367         Jalin Turner 2023-12-02          Bobby Green   Lightweight
# 14752         Bobby Green 2023-12-02         Jalin Turner   Lightweight
# 14753            Rob Font 2023-12-02  Deiveson Figueiredo  Bantamweight
# 14754     Kelvin Gastelum 2023-12-02           Sean Brady  Welterweight
# ...                   ...        ...                  ...           ...
# 7383          Scott Baker 1994-03-11        Remco Pardoel   Open Weight
# 7384   Alberta Cerra Leon 1994-03-11        Johnny Rhodes   Open Weight
# 7385     Robert Lucarelli 1994-03-11        Patrick Smith   Open Weight
# 7386      Thaddeus Luster 1994-03-11         Royce Gracie   Open Weight
# 7382      Minoki Ichihara 1994-03-11         Royce Gracie   Open Weight
#
#        Total_KD  Total_STR  Total_TD  Total_SUB  Opp_KD  Opp_STR  Opp_TD  \
# 14763         7        772        26         12       2      468      28
# 7367          5        416         4          7       4     1653      20
# 14752         4       1653        20          5       5      416       4
# 14753         7       1160        13          5      11      516      16
# 14754         9       1040        19          2       1      313      14
# ...         ...        ...       ...        ...     ...      ...     ...
# 7383          0          0         0          0       0        1       0
# 7384          0          0         0          0       0        4       0
# 7385          0          0         0          0       0        1       0
# 7386          0          0         0          0       1       26       3
# 7382          0          0         0          0       1       24       2
#
#        Opp_SUB  Round   Time  Target  Avg_Round_Time  Avg_Round
# 14763        0    1.0   64.0       0      266.909091   2.409091
# 7367         5    1.0  169.0       1      309.000000   2.900000
# 14752        7    1.0  169.0       0      374.956522   3.521739
# 14753       20    3.0  300.0       0      364.312500   4.062500
# 14754        4    3.0  103.0       0      372.238095   4.333333
# ...        ...    ...    ...     ...             ...        ...
# 7383         1    1.0  401.0       0        0.000000   0.000000
# 7384         0    1.0  591.0       0        0.000000   0.000000
# 7385         0    1.0  170.0       0        0.000000   0.000000
# 7386         3    1.0  292.0       0        0.000000   0.000000
# 7382         1    1.0  308.0       0        0.000000   0.000000
#
# [14764 rows x 17 columns]

# %%
fighter1 = "Khabib Nurmagomedov"
fighter2 = "Conor McGregor"

# %%
fighter1_info = df[df['Fighter'].str.contains(fighter1, case=False)].head(1)

fighter1_info = fighter1_info[['Weight_Class', 'Total_KD', 
                               'Total_STR', 'Total_TD', 'Total_SUB', 
                               'Avg_Round_Time', 'Avg_Round']]

fighter1_info
# Out:
#      Weight_Class  Total_KD  Total_STR  Total_TD  Total_SUB  Avg_Round_Time  \
# 5768  Lightweight         2        679        59          8          226.75
#
#       Avg_Round
# 5768        3.0

# %%
fighter2_info = df[df['Fighter'].str.contains(fighter2, case=False)].head(1)

fighter2_info = fighter2_info[['Weight_Class', 'Total_KD', 
                               'Total_STR', 'Total_TD', 'Total_SUB', 
                               'Avg_Round_Time', 'Avg_Round']]

fighter2_info
# Out:
#       Weight_Class  Total_KD  Total_STR  Total_TD  Total_SUB  Avg_Round_Time  \
# 13509  Lightweight        13        572         5          0      218.461538
#
#        Avg_Round
# 13509   2.692308

# %%
import joblib

model = joblib.load("saved_models/RandomForestClassifierModel.joblib")
